# %%
import pandas as pd

# %%
read_csv = pd.read_csv("c:/users/musfik/documents/Copy of Fortune_10.csv")
read_csv
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth Date Date Time
# 0  6,482,465 Dollars   5274553    30%  Yes  1/2/2024
# 1    916,455 Dollars  11412916    20%  Yes  1/3/2024
# 2  7,591,189 Dollars   3005820     7%  Yes  1/4/2024
# ...

# %%
read_csv.interpolate()
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth Date Date Time
# 0  6,482,465 Dollars   5274553    30%  Yes  1/2/2024
# 1    916,455 Dollars  11412916    20%  Yes  1/3/2024
# 2  7,591,189 Dollars   3005820     7%  Yes  1/4/2024
# ...

# %%
read_csv.interpolate(method="time")
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth Date Date Time
# 0  6,482,465 Dollars   5274553    30%  Yes  1/2/2024
# 1    916,455 Dollars  11412916    20%  Yes  1/3/2024
# 2  7,591,189 Dollars   3005820     7%  Yes  1/4/2024
# ...

# %%
read_csv = pd.read_csv("c:/users/musfik/documents/Copy of Fortune_10.csv",parse_dates=["Date Time"],index_col="dateTime")
read_csv
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f67789b5876f> in <module>()
# ----> 1 read_csv = pd.read_csv("c:/users/musfik/documents/Copy of Fortune_10.csv",parse_dates=["Date Time"],index_col="Date Time")
#       2 read_csv
#
# ...

# %%
read_csv.interpolate()
# Out:
#             ID             Name             Industry  Inception       Revenue  \
# Date Time
# 2024-01-02   1          Lamtone          IT Services       2009  $11,757,018
# 2024-01-03   2        Stripfind   Financial Services       2010  $12,329,371
# 2024-01-04   3  Canecorporation               Health       2012  $10,597,009
# 2024-01-05   4         Mattouch          IT Services       2013  $14,026,934
# NaT          5        Techdrill               Health       2009  $10,573,990
# NaT          6         Techline               Health       2006  $13,898,119
# NaT          7          Cityace               Health       2010   $9,254,614
# 2024-01-09   8   Kayelectronics               Health       2009   $9,451,943
# 2024-01-10   9          Ganzlax          IT Services       2011  $14,001,180
# 2024-01-11  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                      Expenses    Profit Growth Date
# Date Time
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-f3f81cb9a45a> in <module>()
# ----> 1 type(read_csv["Date Time[0]"])
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
# ...
