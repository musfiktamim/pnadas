# %%
import pandas as pd

# %%
read_csv = pd.read_csv("c:/users/musfik/documents/Copy of Fortune_10.csv")
read_csv
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services     2009.0  $11,757,018
# 1   2        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  Canecorporation               Health     2012.0  $10,597,009
# 3   4         Mattouch          IT Services     2013.0  $14,026,934
# 4   5        Techdrill               Health     2009.0  $10,573,990
# 5   6         Techline               Health     2006.0  $13,898,119
# 6   7              NaN               Health     2010.0   $9,254,614
# 7   8   Kayelectronics                  NaN     2009.0   $9,451,943
# 8   9          Ganzlax          IT Services     2011.0           NaN
# 9  10      Trantraxlax  Government Services        NaN  $11,088,336
#
#             Expenses    Profit Growth Date
# 0  6,482,465 Dollars   5274553    30%  Yes
# 1    916,455 Dollars  11412916    20%  Yes
# 2  7,591,189 Dollars   3005820     7%  Yes
# ...

# %%
read_csv.fillna(0)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services     2009.0  $11,757,018
# 1   2        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3  Canecorporation               Health     2012.0  $10,597,009
# 3   4         Mattouch          IT Services     2013.0  $14,026,934
# 4   5        Techdrill               Health     2009.0  $10,573,990
# 5   6         Techline               Health     2006.0  $13,898,119
# 6   7                0               Health     2010.0   $9,254,614
# 7   8   Kayelectronics                    0     2009.0   $9,451,943
# 8   9          Ganzlax          IT Services     2011.0             0
# 9  10      Trantraxlax  Government Services        0.0  $11,088,336
#
#             Expenses    Profit Growth Date
# 0  6,482,465 Dollars   5274553    30%  Yes
# 1    916,455 Dollars  11412916    20%  Yes
# 2  7,591,189 Dollars   3005820     7%  Yes
# ...

# %%
read_csv.fillna(10)
